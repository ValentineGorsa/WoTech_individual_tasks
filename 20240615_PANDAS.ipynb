# %% [markdown]
# <a href="https://colab.research.google.com/github/ValentineGorsa/WoTech_individual_tasks/blob/main/20240615_PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
filename = input(f'Please, enter the path of file: ') #'/content/births.txt' #location

try:
  with open(filename, 'r') as file:
    content = file.read()

    print('Standard File I/O')
    print(content)
except:
  print(f'The file is not found')
# Out:
# Please, enter the path of file: /content/bjjjirths.txt
# The file is not found

# %%
for line in content:
  print(line)
# Out:
# J
# a
# n
#
# 1
# 0
# 4
# 8
#
#
# F
# e
# b
#
# 9
# 8
# 9
#
#
# M
# a
# r
#
# 1
# 1
# 0
# 8
#
#
# A
# p
# r
#
# 1
# 2
# 0
# 7
#
#
# M
# a
# y
#
# 1
# 1
# 8
# 6
#
#
# J
# u
# n
#
# 1
# 1
# 5
# 5
#
#
# J
# u
# l
#
# 1
# 3
# 9
# 1
#
#
# A
# u
# g
#
# 1
# 3
# 0
# 5
#
#
# S
# e
# p
#
# 1
# 2
# 2
# 6
#
#
# O
# c
# t
#
# 1
# 1
# 5
# 5
#
#
# N
# o
# v
#
# 1
# 0
# 1
# 7
#
#
# D
# e
# c
#
# 1
# 1
# 1
# 1

# %% [markdown]
# ### READLINES

# %%
filename = '/content/births.txt' #location

with open(filename, 'r') as file:
  content = file.readlines()

  for line in content:
    print(line, end='')
# Out:
# Jan 1048
# Feb 989
# Mar 1108
# Apr 1207
# May 1186
# Jun 1155
# Jul 1391
# Aug 1305
# Sep 1226
# Oct 1155
# Nov 1017
# Dec 1111

# %%
# Open the file in read mode
with open('/content/births.txt', 'r') as file:
    # Read all lines from the file
    births = file.readlines()

total_sum = 0

# Iterate through each line in the list and print it
for birthline in births:
  value = int(birthline[4:])
  total_sum +=value

    #print(birthline[4:])
print(total_sum)
# Out:
# 13898

# %%
# births
with open('/content/births.txt', 'r') as file:
    births = file.readlines()

# deaths
with open('/content/deaths.txt', 'r') as file:
    deaths = file.readlines()

# accessing the number: int(birtline[4:])

for i in range(len(births)):
  birthline = births[i]
  deathline = deaths[i]

  birthnumber = int(birthline[4:])
  deathnumber = int(deathline[4:])

  growth = birthnumber - deathnumber
  month = birthline[0:3]
  if growth > 0:
    print(f'{month}: {growth}')
  #print(birthnumber, deathnumber)
  #print(growth)
# Out:
# Jun: 40
# Jul: 64
# Aug: 103
# Sep: 49

# %% [markdown]
# Task (in your free time): put all this in a function, where parameters are deaths.txt and births.txt

# %% [markdown]
# ###PANDAS data exploration

# %%
import pandas as pd #obveration of pandas
births = pd.read_csv('/content/births.txt', header = None, delimiter = ' ') #able read many different file types
deaths = pd.read_csv('/content/deaths.txt')

#births
birth_column_names = ['Month', 'Nr. of births']
births.columns = birth_column_names
births
# Out:
#    Month  Nr. of births
# 0    Jan           1048
# 1    Feb            989
# 2    Mar           1108
# 3    Apr           1207
# 4    May           1186
# 5    Jun           1155
# 6    Jul           1391
# 7    Aug           1305
# 8    Sep           1226
# 9    Oct           1155
# 10   Nov           1017
# 11   Dec           1111

# %%
import pandas as pd #obveration of pandas
deaths = pd.read_csv('/content/deaths.txt', header = None, delimiter = ' ') #able read many different file types

death_column_names = ['Month', 'Nr. of deaths']
deaths.columns = death_column_names
deaths
# Out:
#    Month  Nr. of deaths
# 0    Jan           1575
# 1    Feb           1167
# 2    Mar           1249
# 3    Apr           1281
# 4    May           1303
# 5    Jun           1115
# 6    Jul           1327
# 7    Aug           1202
# 8    Sep           1177
# 9    Oct           1265
# 10   Nov           1218
# 11   Dec           1359

# %%
births['Saldo'] = births['Nr. of births'] - deaths['Nr. of deaths']
births
# Out:
#    Month  Nr. of births  Nr. of deaths  Saldo
# 0    Jan           1048           1575   -527
# 1    Feb            989           1167   -178
# 2    Mar           1108           1249   -141
# 3    Apr           1207           1281    -74
# 4    May           1186           1303   -117
# 5    Jun           1155           1115     40
# 6    Jul           1391           1327     64
# 7    Aug           1305           1202    103
# 8    Sep           1226           1177     49
# 9    Oct           1155           1265   -110
# 10   Nov           1017           1218   -201
# 11   Dec           1111           1359   -248

# %%
births['Month']
# Out:
# 0     Jan
# 1     Feb
# 2     Mar
# 3     Apr
# 4     May
# 5     Jun
# 6     Jul
# 7     Aug
# 8     Sep
# 9     Oct
# 10    Nov
# 11    Dec
# Name: Month, dtype: object

# %%
births['Nr. of deaths'] = deaths['Nr. of deaths']
# Out:
#    Month  Nr. of births  Nr. of deaths
# 0    Jan           1048           1575
# 1    Feb            989           1167
# 2    Mar           1108           1249
# 3    Apr           1207           1281
# 4    May           1186           1303
# 5    Jun           1155           1115
# 6    Jul           1391           1327
# 7    Aug           1305           1202
# 8    Sep           1226           1177
# 9    Oct           1155           1265
# 10   Nov           1017           1218
# 11   Dec           1111           1359

# %%
births
# Out:
#    Month  Nr. of births  Nr. of deaths  Saldo
# 0    Jan           1048           1575   -527
# 1    Feb            989           1167   -178
# 2    Mar           1108           1249   -141
# 3    Apr           1207           1281    -74
# 4    May           1186           1303   -117
# 5    Jun           1155           1115     40
# 6    Jul           1391           1327     64
# 7    Aug           1305           1202    103
# 8    Sep           1226           1177     49
# 9    Oct           1155           1265   -110
# 10   Nov           1017           1218   -201
# 11   Dec           1111           1359   -248

# %%
#Exporting data
file_name = '/content/output.csv'
births.to_csv(file_name, index=False)

# %% [markdown]
# ### Individual task "prices.txt"

# %%
# Open the file in read mode
with open('/content/prices.txt', 'r') as file:
    # Read all lines from the file
    prices = file.readlines()

total_price = 0.0
total_count = 0

# Iterate through each line in the list and print it
for priceline in prices:
    try:
      price = float(priceline)
      total_price +=price
      total_count +=1
    except:
      pass

print(f'Total Price: {total_price}')
print(f'Total Number of Purchased Items: {total_count}')
# Out:
# Total Price: 17.32
# Total Number of Purchased Items: 5
